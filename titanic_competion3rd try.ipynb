# %%
import pandas as pd

# %%
data=pd.read_csv('/content/sample_data/Titanic_train.csv')

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pip install pycaret
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 483.9/483.9 kB 7.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 34.4/34.4 MB 42.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 153.4/153.4 kB 17.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 81.8/81.8 kB 9.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 19.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 79.9/79.9 MB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 106.8/106.8 kB 10.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 73.4/73.4 kB 8.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.1/17.1 MB 52.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.0/44.0 kB 4.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 62.1 MB/s eta 0:00:00
# ...

# %%
from pycaret.classification import *

# Initialize PyCaret setup
clf1 = setup(data, target="Survived")

# Compare and evaluate multiple models
best_model = compare_models()

# Print the best model
print(best_model)
# Out:
# <style type="text/css">
# #T_e160f_row11_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_e160f" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_e160f_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_e160f_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e160f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e160f_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_e160f_row0_col1" class="data row0 col1" >1409</td>
#     </tr>
#     <tr>
#       <th id="T_e160f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_e160f_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_e160f_row1_col1" class="data row1 col1" >Survived</td>
#     </tr>
#     <tr>
#       <th id="T_e160f_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
# Tune the hyperparameters of the best model (optional)
tuned_best_model = tune_model(best_model)

# Evaluate the tuned model on the test dataset (optional)
evaluate_model(tuned_best_model)

# You can also use the best model for predictions
predictions = predict_model(tuned_best_model, data=new_data)
# Out:
# <style type="text/css">
# #T_f941b_row10_col0, #T_f941b_row10_col1, #T_f941b_row10_col2, #T_f941b_row10_col3, #T_f941b_row10_col4, #T_f941b_row10_col5, #T_f941b_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_f941b" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f941b_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_f941b_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_f941b_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_f941b_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_f941b_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_f941b_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_f941b_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
# Create and train a logistic regression model using the entire dataset
logistic_regression_model = create_model("lr")  # "lr" is the identifier for logistic regression

# Load your test dataset (replace 'test_data.csv' with the path to your test dataset)
test_data = pd.read_csv("/content/sample_data/Titanic_test.csv")

# Make predictions on the test dataset using the logistic regression model
predictions = predict_model(logistic_regression_model, data=test_data)
# Out:
# <style type="text/css">
# #T_84b4a_row10_col0, #T_84b4a_row10_col1, #T_84b4a_row10_col2, #T_84b4a_row10_col3, #T_84b4a_row10_col4, #T_84b4a_row10_col5, #T_84b4a_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_84b4a" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84b4a_level0_col0" class="col_heading level0 col0" >Accuracy</th>
#       <th id="T_84b4a_level0_col1" class="col_heading level0 col1" >AUC</th>
#       <th id="T_84b4a_level0_col2" class="col_heading level0 col2" >Recall</th>
#       <th id="T_84b4a_level0_col3" class="col_heading level0 col3" >Prec.</th>
#       <th id="T_84b4a_level0_col4" class="col_heading level0 col4" >F1</th>
#       <th id="T_84b4a_level0_col5" class="col_heading level0 col5" >Kappa</th>
#       <th id="T_84b4a_level0_col6" class="col_heading level0 col6" >MCC</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >Fold</th>
# ...

# %%
predictions
# Out:
#      PassengerId  Pclass                                          Name  \
# 0            892       3                              Kelly, Mr. James
# 1            893       3              Wilkes, Mrs. James (Ellen Needs)
# 2            894       2                     Myles, Mr. Thomas Francis
# 3            895       3                              Wirz, Mr. Albert
# 4            896       3  Hirvonen, Mrs. Alexander (Helga E Lindqvist)
# ..           ...     ...                                           ...
# 413         1305       3                            Spector, Mr. Woolf
# 414         1306       1                  Oliva y Ocana, Dona. Fermina
# 415         1307       3                  Saether, Mr. Simon Sivertsen
# 416         1308       3                           Ware, Mr. Frederick
# 417         1309       3                      Peter, Master. Michael J
#
#         Sex   Age  SibSp  Parch              Ticket        Fare Cabin  \
# ...

# %%
ok=predictions.prediction_label

# %%
submission=test_data['PassengerId']

# %%
submission
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
submission['Survived']=ok

# %%
submission
# Out:
# 0       892
# 1       893
# 2       894
# 3       895
# 4       896
#        ...
# 413    1305
# 414    1306
# 415    1307
# 416    1308
# 417    1309
# Name: PassengerId, Length: 418, dtype: int64

# %%
submission = pd.DataFrame({'PassengerId' :submission ,'Survived': ok})

# %% [markdown]
# submission

# %%
submission
# Out:
#      PassengerId  Survived
# 0            892         0
# 1            893         0
# 2            894         0
# 3            895         0
# 4            896         1
# ..           ...       ...
# 413         1305         0
# 414         1306         1
# 415         1307         0
# 416         1308         0
# 417         1309         0
#
# [418 rows x 2 columns]

# %%
submission.to_csv("predicted_labels.csv", index=None)

# %%
import os
os.getcwd()
# Out:
# '/content'

# %%
# The 'Label' column in the 'predictions' DataFrame contains the predicted labels
predicted_labels = predictions['Survived']

# Optionally, you can save the predictions to a CSV file
predicted_labels.to_csv("predicted_labels.csv", index=None)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /usr/local/lib/python3.10/dist-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    3801             try:
# -> 3802                 return self._engine.get_loc(casted_key)
#    3803             except KeyError as err:
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# /usr/local/lib/python3.10/dist-packages/pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Survived'
#
# The above exception was the direct cause of the following exception:
#
# ...
